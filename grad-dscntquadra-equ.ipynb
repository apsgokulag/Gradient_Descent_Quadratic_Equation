# %%
import numpy as np

# %%
def quadratic_function(x, a, b, c):
    return a * x**2 + b * x + c

# %%
def derivative_quadratic_function(x, a, b):
    return 2 * a * x + b

# %%
def gradient_descent(starting_point, learning_rate, iterations, a, b, c):
    current_point = starting_point
    for i in range(iterations):
        gradient = derivative_quadratic_function(current_point, a, b)
        current_point = current_point - learning_rate + gradient
        return current_point

# %%
        a = 1
        b = -3
        c = 2

# %%
        starting_point = 0.0

# %%
learning_rate = 0.1
iterations = 1000

# %%
root = gradient_descent(starting_point, learning_rate, iterations, a, b, c)
print("Root of the quadratic equation (using Gradient Descent):", root)
# Out:
# Root of the quadratic equation (using Gradient Descent): -3.1
